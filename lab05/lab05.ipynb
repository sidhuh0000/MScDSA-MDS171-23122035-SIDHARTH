# %% [markdown]
# Mix & Match Calculator
#
# Create Lists for [Item, Quantity, Price] with 10 random values of your choice.
# The item list can be of any category of your choice [Food Items, Grocery Items,...] or anything you choose that can be bought.
#
# Prepare a CSV file with combinations of these values with the help of random index & looping statements and other control structures we discussed in class.
#
# To get a random index or number to access items from the list, you can use the following:
# random is a library in Python that can be used to generate random numbers.
#
# import random # Importing the external library
# r1 = random.randint(0, 10) # Generating the random number from the range and store it in r1 variable
#
# More details of the Random library usage can be found here.
#
# Your CSV file should have a minimum of 100 rows created randomly with the data in the list and the random library.
# Each row in the CSV file will have (item, Quantity, and UnitPrice).
#
# After preparing the CSV with Python code, you need to compute
# The total cost for each row, display the result from the first 5 rows and the last 10 rows
# Calculate the total cost for each unique item in the dataset.
# Item Name | Total Quantity | Total
# Print the minimum & maximum price for each item sold

# %%
import random
def Item_list():
    Item=["Rice","Weat","Coffee_Powder","Chilli Powder","Turmeric_Powder","Salt","Cooking_Oil","Sugar","Pepper_Powder","Vegetables"]
    Quantity=["1","2","5","1","2","3","10","6","7","8","6"]
    Price=["250","100","80","160","140","100","100","140","100","160"]
    Total = []

    file = open("23122035.csv","w+")
    for i in range(100):
        Items = random.randint(0, 9)
        int_Quantity = int(Quantity[Items])
        int_Price = int(Price[Items])
        total_price= int_Quantity*int_Price
        total = str(total_price)
        file.write(Item[Items]+","+Quantity[Items]+","+Price[Items]+","+"\t Total = "+total+"\n")
        
        



    file.close()
Item_list()

# %%
file = open("23122035.csv","r+")
for lines in range(90,100):
    lines = file.readline()
    print(lines)
# Out:
# Coffee Powder,5,80,	 Total = 400
#
# Cooking Oil,10,100,	 Total = 1000
#
# Sugar,6,140,	 Total = 840
#
# Sugar,6,140,	 Total = 840
#
# Coffee Powder,5,80,	 Total = 400
#
# Sugar,6,140,	 Total = 840
#
# Coffee Powder,5,80,	 Total = 400
#
# Turmeric Powder,2,140,	 Total = 280
#
# Pepper Powder,7,100,	 Total = 700
#
# Weat,2,100,	 Total = 200

# %%
with open("23122035.csv","r+") as file:
    for lines in file:
        if "rice" in lines:

            line=lines.split()
print(line)

with open("23122035.csv","r+") as file:
    for lines in file:
        if "Weat" in lines:

            line=lines.split()
print(line)

with open("23122035.csv","r+") as file:
    for lines in file:
        if "Coffee_Powder" in lines:

            line=lines.split()
print(line)


with open("23122035.csv","r+") as file:
    for lines in file:
        if "Chilli_Powder" in lines:

            line=lines.split()
print(line)
with open("23122035.csv","r+") as file:
    for lines in file:
        if "Turmeric_Powder" in lines:

            line=lines.split()
print(line)
with open("23122035.csv","r+") as file:
    for lines in file:
        if "Salt" in lines:

            line=lines.split()
print(line)
with open("23122035.csv","r+") as file:
    for lines in file:
        if "Cooking_Oil" in lines:

            line=lines.split()
print(line)
with open("23122035.csv","r+") as file:
    for lines in file:
        if "Sugar" in lines:

            line=lines.split()
print(line)
with open("23122035.csv","r+") as file:
    for lines in file:
        if "Pepper_Powder" in lines:

            line=lines.split()
print(line)
with open("23122035.csv","r+") as file:
    for lines in file:
        if "Vegetables" in lines:

            line=lines.split()
print(line)
# Out:
# Salt,3,100,	 Total = 300
#
# ['Weat,2,100,', 'Total', '=', '200']
# ['Weat,2,100,', 'Total', '=', '200']
# ['Weat,2,100,', 'Total', '=', '200']
# ['Weat,2,100,', 'Total', '=', '200']
# ['Salt,3,100,', 'Total', '=', '300']
# ['Salt,3,100,', 'Total', '=', '300']
# ['Sugar,6,140,', 'Total', '=', '840']
# ['Sugar,6,140,', 'Total', '=', '840']
# ['Vegetables,8,160,', 'Total', '=', '1280']
